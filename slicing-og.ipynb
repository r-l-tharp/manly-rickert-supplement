# %%
# Always run this at the start

from PIL import Image, ImageFilter, ImageChops

# %%
# Testing for correct pixels

top = 100
bottom = 1500
right = 1500
left = 0

image = Image.open("./B1881_example.jpg") # TODO: Use correct directory
cropped = image.crop((left, top, right, bottom))
display(cropped)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1500x1400 at 0x7F84CBD7AEE0>

# %%
# Looping through cards

# Get all files in the folder
import os
all_files = os.listdir("./data") # TODO: Use correct directory

# Coordinates for all boxes
# (left, top, right, bottom)
box_1 = (0, 100, 1500, 1500)
# TODO: More boxes

# Loop through all files in the folder:
for file in all_files:
    # Get the name of the file (use as id) (remove .jpg extension)
    name = file[:-4]
    # Create sliced images
    image = Image.open('./data/' + file) # TODO: Use correct directory
    # box 1
    image.crop(box_1).save('./cropped/' + name + '_box_1.jpg') # TODO: Use correct directory
    # TODO: More boxes
# Out:
# box_1
# B1881_example
