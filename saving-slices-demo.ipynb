# %%
from PIL import Image, ImageFilter, ImageChops
# above line must be in same box as below lines
image = Image.open("./B1881_example.jpg")
cropped = image.crop((0, 50, 1325, 1715))
# eventually you'll add a folder name (./cropped/box...)
cropped.save('./box_1.jpg')
saved = Image.open('./box_1.jpg')
display(saved)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1325x1665>
