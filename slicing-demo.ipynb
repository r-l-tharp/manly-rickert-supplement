# %%
from PIL import Image, ImageFilter, ImageChops

# %%
image = Image.open("./B1881_example.jpg")
cropped = image.crop((left, top, right, bottom))
display(cropped)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11664\2508559621.py in <module>
#       1 image = Image.open("./B1881_example.jpg")
# ----> 2 cropped = image.crop((left, top, right, bottom))
#       3 display(cropped)
#
# c:\Users\rlcom\anaconda3\envs\mrsenv\lib\site-packages\PIL\Image.py in crop(self, box)
#    1169
#    1170         if box[2] < box[0]:
# -> 1171             raise ValueError("Coordinate 'right' is less than 'left'")
#    1172         elif box[3] < box[1]:
#    1173             raise ValueError("Coordinate 'lower' is less than 'upper'")
#
# ValueError: Coordinate 'right' is less than 'left'

# %%
top = 1920
bottom = 2115
right = 3180
left = 0

cropped = image.crop((left, top, right, bottom))
display(cropped)
# Out:
# <PIL.Image.Image image mode=RGB size=3180x195>
